# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_error
from xgboost import XGBRegressor

# %%
from dataset import make_dataset
from os.path import join


train_path = join('jeju_data', 'train_new.parquet')
test_path = join('jeju_data', 'test_new.parquet')

x_train, y_train, test = make_dataset(train_path, test_path)
# Out:
# 시작시간: 2022-10-19 16:19:08.777020
# Train dataset success !
# Test dataset success !
# 끝난 시간:  0:01:06.690466

# %%
x_train['height_restricted'].value_counts()
# Out:
# 0.0    4701217
# Name: height_restricted, dtype: int64

# %%
x_train.corr('')
# Out:
#                        day_of_week  lane_count  road_rating  multi_linked  \
# day_of_week               1.000000    0.001426    -0.002274     -0.000084
# lane_count                0.001426    1.000000    -0.095717     -0.026555
# road_rating              -0.002274   -0.095717     1.000000      0.024218
# multi_linked             -0.000084   -0.026555     0.024218      1.000000
# connect_code             -0.000002   -0.029290    -0.054160     -0.001111
# maximum_speed_limit       0.001651    0.384002    -0.327474     -0.020245
# weight_restricted         0.000158   -0.177224    -0.118630     -0.008790
# height_restricted              NaN         NaN          NaN           NaN
# road_type                 0.000429   -0.050715    -0.125618      0.042977
# start_latitude            0.001201    0.182674    -0.204793     -0.014906
# start_longitude           0.000656   -0.094806     0.007401      0.026895
# start_turn_restricted     0.000879    0.292852    -0.029050     -0.007202
# end_latitude              0.001214    0.182330    -0.204843     -0.014907
# end_longitude             0.000664   -0.094732     0.007386      0.026896
# end_turn_restricted       0.000949    0.312854    -0.029451     -0.007203
# distance                  0.000344   -0.167181     0.049795     -0.015815
# week                      0.478516    0.001696    -0.001793     -0.000384
# over_max_speed            0.000070   -0.191700     0.149703     -0.005025
# time                      0.003479   -0.030113     0.032722      0.005611
# sin_time                 -0.001596    0.023453    -0.024881     -0.005729
# cos_time                 -0.006327    0.036228    -0.028977     -0.013184
# month                    -0.047578    0.003799    -0.003700     -0.002193
# post_holiday              0.084221   -0.002185    -0.005795     -0.000485
# pre_holiday               0.035330   -0.003379    -0.004987      0.000245
# holiday                   0.085495   -0.000099    -0.006821     -0.000273
# season                    0.006648    0.023891     0.027936     -0.001254
# vacation                  0.031907    0.026053     0.016807     -0.000354
#
#                        connect_code  maximum_speed_limit  weight_restricted  \
# day_of_week               -0.000002             0.001651           0.000158
# lane_count                -0.029290             0.384002          -0.177224
# road_rating               -0.054160            -0.327474          -0.118630
# multi_linked              -0.001111            -0.020245          -0.008790
# connect_code               1.000000            -0.015190          -0.020491
# maximum_speed_limit       -0.015190             1.000000           0.085080
# weight_restricted         -0.020491             0.085080           1.000000
# height_restricted               NaN                  NaN                NaN
# road_type                 -0.025846             0.059511           0.792803
# start_latitude             0.036623             0.253147          -0.128291
# start_longitude           -0.045695            -0.033018           0.034926
# start_turn_restricted     -0.016789             0.094124          -0.119699
# end_latitude               0.037163             0.252958          -0.128305
# end_longitude             -0.044853            -0.032907           0.034915
# end_turn_restricted       -0.016791             0.104737          -0.119564
# distance                  -0.006181             0.052220          -0.278254
# week                       0.000078             0.000892           0.000215
# over_max_speed             0.118464            -0.587448          -0.041521
# time                      -0.002700            -0.038017          -0.003351
# sin_time                   0.001956             0.029782           0.003105
# cos_time                   0.002867             0.037952           0.001235
# month                      0.005092             0.001396           0.000740
# post_holiday               0.001845             0.007401           0.003242
# pre_holiday                0.001781             0.006164           0.003077
# holiday                    0.002209             0.009261           0.003013
# season                    -0.012874            -0.030243          -0.018124
# vacation                  -0.008173            -0.021201          -0.014715
#
#                        height_restricted  road_type  start_latitude  ...  \
# day_of_week                          NaN   0.000429        0.001201  ...
# lane_count                           NaN  -0.050715        0.182674  ...
# road_rating                          NaN  -0.125618       -0.204793  ...
# multi_linked                         NaN   0.042977       -0.014906  ...
# connect_code                         NaN  -0.025846        0.036623  ...
# maximum_speed_limit                  NaN   0.059511        0.253147  ...
# weight_restricted                    NaN   0.792803       -0.128291  ...
# height_restricted                    NaN        NaN             NaN  ...
# road_type                            NaN   1.000000       -0.043420  ...
# start_latitude                       NaN  -0.043420        1.000000  ...
# start_longitude                      NaN   0.033684        0.127042  ...
# start_turn_restricted                NaN  -0.103950        0.282428  ...
# end_latitude                         NaN  -0.043430        0.999106  ...
# end_longitude                        NaN   0.033664        0.127005  ...
# end_turn_restricted                  NaN  -0.103781        0.282798  ...
# distance                             NaN  -0.317430        0.127786  ...
# week                                 NaN   0.000896        0.000654  ...
# over_max_speed                       NaN  -0.062335       -0.125803  ...
# time                                 NaN  -0.008167       -0.022367  ...
# sin_time                             NaN   0.006400        0.017302  ...
# cos_time                             NaN   0.005206        0.021535  ...
# month                                NaN   0.003837       -0.000004  ...
# post_holiday                         NaN   0.000832        0.005816  ...
# pre_holiday                          NaN   0.000671        0.005595  ...
# holiday                              NaN   0.001062        0.006861  ...
# season                               NaN  -0.003940       -0.028384  ...
# vacation                             NaN  -0.000268       -0.023574  ...
#
#                        over_max_speed      time  sin_time  cos_time     month  \
# day_of_week                  0.000070  0.003479 -0.001596 -0.006327 -0.047578
# lane_count                  -0.191700 -0.030113  0.023453  0.036228  0.003799
# road_rating                  0.149703  0.032722 -0.024881 -0.028977 -0.003700
# multi_linked                -0.005025  0.005611 -0.005729 -0.013184 -0.002193
# connect_code                 0.118464 -0.002700  0.001956  0.002867  0.005092
# maximum_speed_limit         -0.587448 -0.038017  0.029782  0.037952  0.001396
# weight_restricted           -0.041521 -0.003351  0.003105  0.001235  0.000740
# height_restricted                 NaN       NaN       NaN       NaN       NaN
# road_type                   -0.062335 -0.008167  0.006400  0.005206  0.003837
# start_latitude              -0.125803 -0.022367  0.017302  0.021535 -0.000004
# start_longitude             -0.102796 -0.011955  0.010973  0.009538  0.000126
# start_turn_restricted        0.002230 -0.012896  0.009991  0.013537  0.000882
# end_latitude                -0.125117 -0.022366  0.017282  0.021528 -0.000037
# end_longitude               -0.102741 -0.011961  0.010967  0.009578  0.000132
# end_turn_restricted         -0.036589 -0.013040  0.009921  0.013725  0.000832
# distance                    -0.034421  0.003658 -0.003454 -0.008071 -0.001833
# week                         0.000601  0.009033 -0.007238 -0.011078 -0.024970
# over_max_speed               1.000000  0.020558 -0.016979 -0.017317  0.001156
# time                         0.020558  1.000000 -0.778058 -0.060022  0.002297
# sin_time                    -0.016979 -0.778058  1.000000 -0.023503 -0.006209
# cos_time                    -0.017317 -0.060022 -0.023503  1.000000  0.000607
# month                        0.001156  0.002297 -0.006209  0.000607  1.000000
# post_holiday                -0.002849  0.022120 -0.014665 -0.016398  0.030835
# pre_holiday                 -0.002689  0.007894 -0.005470 -0.002507  0.005284
# holiday                     -0.003434  0.027320 -0.017754 -0.021902  0.000727
# season                       0.011548 -0.016987  0.021525  0.007361 -0.346387
# vacation                     0.010913 -0.002871  0.000888  0.006726 -0.641409
#
#                        post_holiday  pre_holiday   holiday    season  vacation
# day_of_week                0.084221     0.035330  0.085495  0.006648  0.031907
# lane_count                -0.002185    -0.003379 -0.000099  0.023891  0.026053
# road_rating               -0.005795    -0.004987 -0.006821  0.027936  0.016807
# multi_linked              -0.000485     0.000245 -0.000273 -0.001254 -0.000354
# connect_code               0.001845     0.001781  0.002209 -0.012874 -0.008173
# maximum_speed_limit        0.007401     0.006164  0.009261 -0.030243 -0.021201
# weight_restricted          0.003242     0.003077  0.003013 -0.018124 -0.014715
# height_restricted               NaN          NaN       NaN       NaN       NaN
# road_type                  0.000832     0.000671  0.001062 -0.003940 -0.000268
# start_latitude             0.005816     0.005595  0.006861 -0.028384 -0.023574
# start_longitude           -0.001759     0.000679 -0.002523 -0.008551 -0.005315
# start_turn_restricted     -0.001845    -0.002599 -0.001246  0.019179  0.018266
# end_latitude               0.005815     0.005602  0.006879 -0.028363 -0.023538
# end_longitude             -0.001742     0.000687 -0.002501 -0.008576 -0.005327
# end_turn_restricted       -0.001504    -0.002487 -0.000761  0.019126  0.018212
# distance                   0.003871     0.004600  0.003536 -0.026556 -0.023644
# week                       0.058773    -0.071988 -0.003609 -0.013775  0.038155
# over_max_speed            -0.002849    -0.002689 -0.003434  0.011548  0.010913
# time                       0.022120     0.007894  0.027320 -0.016987 -0.002871
# sin_time                  -0.014665    -0.005470 -0.017754  0.021525  0.000888
# cos_time                  -0.016398    -0.002507 -0.021902  0.007361  0.006726
# month                      0.030835     0.005284  0.000727 -0.346387 -0.641409
# post_holiday               1.000000     0.094341  0.218793 -0.083791 -0.050080
# pre_holiday                0.094341     1.000000  0.213776 -0.055976 -0.046742
# holiday                    0.218793     0.213776  1.000000 -0.057993 -0.044660
# season                    -0.083791    -0.055976 -0.057993  1.000000  0.078617
# vacation                  -0.050080    -0.046742 -0.044660  0.078617  1.000000
#
# [27 rows x 27 columns]

# %%
x_train.columns
# Out:
# Index(['day_of_week', 'lane_count', 'road_rating', 'multi_linked',
#        'connect_code', 'maximum_speed_limit', 'weight_restricted',
#        'height_restricted', 'road_type', 'start_latitude', 'start_longitude',
#        'start_turn_restricted', 'end_latitude', 'end_longitude',
#        'end_turn_restricted', 'distance', 'week', 'over_max_speed', 'time',
#        'sin_time', 'cos_time', 'month', 'post_holiday', 'pre_holiday',
#        'holiday', 'season', 'vacation'],
#       dtype='object')

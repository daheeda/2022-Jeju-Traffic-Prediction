# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_error
from xgboost import XGBRegressor
from dataset_test import make_dataset
from os.path import join


train_path = join('jeju_data', 'train_new.parquet')
test_path = join('jeju_data', 'test_new.parquet')

x_train, y_train, test = make_dataset(train_path, test_path)
# Out:
# Start time:  2022-10-22 14:39:18.596475
# Train dataset success !
# Test dataset success !
# End time: 2022-10-22 14:40:30.984163
# Play time:  0:01:12.387688

# %%
X = x_train.copy()
y = y_train.copy()

# x_train, x_val, y_train, y_val = train_test_split(x_train, y_train, test_size=0.2, shuffle=True, random_state=1103)

# %%
import optuna
from optuna import Trial
from optuna.samplers import TPESampler


def objective_xgb(trial: Trial, x, y):
    params = {
        "n_estimators": trial.suggest_int('n_estimators', 500, 5000),
        'max_depth': trial.suggest_int('max_depth', 8, 16),
        'min_child_weight': trial.suggest_int('min_child_weight', 1, 300),
        'gamma': trial.suggest_int('gamma', 1, 3),
        'learning_rate': trial.suggest_categorical('learning_rate', [0.008,0.01,0.012,0.014,0.016,0.018, 0.02]),
        "colsample_bytree": trial.suggest_float("colsample_bytree", 0.5, 1.0),
        'lambda': trial.suggest_loguniform('lambda', 1e-3, 10.0),
        'alpha': trial.suggest_loguniform('alpha', 1e-3, 10.0),
        'subsample': trial.suggest_categorical('subsample', [0.6, 0.7, 0.8, 1.0]),
        'random_state': 42
    }

    x_train, x_val, y_train, y_val = train_test_split(x, y, test_size=0.3)

    model = XGBRegressor(**params, tree_method='gpu_hist', gpu_id=0)
    xgb_model = model.fit(x_train, y_train, verbose=False, eval_set=[(x_val, y_val)], early_stopping_rounds=50)
    y_pred = xgb_model.predict(x_val)
    score = mean_absolute_error(y_val, y_pred)

    return score


study = optuna.create_study(direction='minimize', sampler=TPESampler())
study.optimize(lambda trial: objective_xgb(trial, X, y), n_trials=30)
print('Best trial: score {},\nparams {}'.format(study.best_trial.value, study.best_trial.params))

params = study.best_trial.params
xgb_model = XGBRegressor(**params, tree_method='gpu_hist', gpu_id=0).fit(x_train, y_train)
y_pred = xgb_model.predict(test)

import pandas as pd

sample_submission = pd.read_csv('./jeju_data/sample_submission.csv')
sample_submission['target'] = y_pred
sample_submission.to_csv("./submit_xgb_optunadelout.csv", index=False)
# Out:
# [I 2022-10-22 14:41:07,918] A new study created in memory with name: no-name-e23f4d61-58b8-4338-bb16-276b3523f20d
# C:\Users\jkpark\AppData\Local\Temp\ipykernel_21308\3082868993.py:14: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   'lambda': trial.suggest_loguniform('lambda', 1e-3, 10.0),
# C:\Users\jkpark\AppData\Local\Temp\ipykernel_21308\3082868993.py:15: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   'alpha': trial.suggest_loguniform('alpha', 1e-3, 10.0),
# c:\Python\Python38\lib\site-packages\xgboost\sklearn.py:793: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# [I 2022-10-22 14:47:00,932] Trial 0 finished with value: 3.145041949676306 and parameters: {'n_estimators': 977, 'max_depth': 14, 'min_child_weight': 287, 'gamma': 3, 'learning_rate': 0.014, 'colsample_bytree': 0.6196607960754024, 'lambda': 0.008556536487634988, 'alpha': 0.0019315291967633202, 'subsample': 0.7}. Best is trial 0 with value: 3.145041949676306.
# C:\Users\jkpark\AppData\Local\Temp\ipykernel_21308\3082868993.py:14: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   'lambda': trial.suggest_loguniform('lambda', 1e-3, 10.0),
# C:\Users\jkpark\AppData\Local\Temp\ipykernel_21308\3082868993.py:15: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   'alpha': trial.suggest_loguniform('alpha', 1e-3, 10.0),
# c:\Python\Python38\lib\site-packages\xgboost\sklearn.py:793: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# [I 2022-10-22 14:51:22,286] Trial 1 finished with value: 3.1310896651926843 and parameters: {'n_estimators': 3563, 'max_depth': 11, 'min_child_weight': 260, 'gamma': 1, 'learning_rate': 0.018, 'colsample_bytree': 0.7089070438190315, 'lambda': 5.947818902054414, 'alpha': 0.007296240358465473, 'subsample': 1.0}. Best is trial 1 with value: 3.1310896651926843.
# C:\Users\jkpark\AppData\Local\Temp\ipykernel_21308\3082868993.py:14: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   'lambda': trial.suggest_loguniform('lambda', 1e-3, 10.0),
# C:\Users\jkpark\AppData\Local\Temp\ipykernel_21308\3082868993.py:15: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   'alpha': trial.suggest_loguniform('alpha', 1e-3, 10.0),
# c:\Python\Python38\lib\site-packages\xgboost\sklearn.py:793: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# [I 2022-10-22 15:16:30,413] Trial 2 finished with value: 3.059911950842838 and parameters: {'n_estimators': 3503, 'max_depth': 16, 'min_child_weight': 169, 'gamma': 3, 'learning_rate': 0.02, 'colsample_bytree': 0.9894318447412749, 'lambda': 0.7597172092599905, 'alpha': 1.0202583471893827, 'subsample': 0.7}. Best is trial 2 with value: 3.059911950842838.
# C:\Users\jkpark\AppData\Local\Temp\ipykernel_21308\3082868993.py:14: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   'lambda': trial.suggest_loguniform('lambda', 1e-3, 10.0),
# C:\Users\jkpark\AppData\Local\Temp\ipykernel_21308\3082868993.py:15: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   'alpha': trial.suggest_loguniform('alpha', 1e-3, 10.0),
# c:\Python\Python38\lib\site-packages\xgboost\sklearn.py:793: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# [I 2022-10-22 15:17:39,563] Trial 3 finished with value: 3.4788672446871907 and parameters: {'n_estimators': 1524, 'max_depth': 8, 'min_child_weight': 121, 'gamma': 3, 'learning_rate': 0.016, 'colsample_bytree': 0.7741689205940596, 'lambda': 1.2129431097391032, 'alpha': 0.0018953448358493199, 'subsample': 0.6}. Best is trial 2 with value: 3.059911950842838.
# C:\Users\jkpark\AppData\Local\Temp\ipykernel_21308\3082868993.py:14: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   'lambda': trial.suggest_loguniform('lambda', 1e-3, 10.0),
# C:\Users\jkpark\AppData\Local\Temp\ipykernel_21308\3082868993.py:15: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   'alpha': trial.suggest_loguniform('alpha', 1e-3, 10.0),
# c:\Python\Python38\lib\site-packages\xgboost\sklearn.py:793: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# [I 2022-10-22 15:20:18,957] Trial 4 finished with value: 3.231824699966706 and parameters: {'n_estimators': 3461, 'max_depth': 8, 'min_child_weight': 9, 'gamma': 1, 'learning_rate': 0.018, 'colsample_bytree': 0.590157550335022, 'lambda': 0.010489406188393835, 'alpha': 0.0814069643516153, 'subsample': 0.7}. Best is trial 2 with value: 3.059911950842838.
# C:\Users\jkpark\AppData\Local\Temp\ipykernel_21308\3082868993.py:14: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   'lambda': trial.suggest_loguniform('lambda', 1e-3, 10.0),
# C:\Users\jkpark\AppData\Local\Temp\ipykernel_21308\3082868993.py:15: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   'alpha': trial.suggest_loguniform('alpha', 1e-3, 10.0),
# c:\Python\Python38\lib\site-packages\xgboost\sklearn.py:793: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# [I 2022-10-22 15:45:34,060] Trial 5 finished with value: 3.0472197719794254 and parameters: {'n_estimators': 3805, 'max_depth': 15, 'min_child_weight': 163, 'gamma': 3, 'learning_rate': 0.018, 'colsample_bytree': 0.9064823571291561, 'lambda': 0.0018755672211178925, 'alpha': 1.8903424357545375, 'subsample': 0.7}. Best is trial 5 with value: 3.0472197719794254.
# C:\Users\jkpark\AppData\Local\Temp\ipykernel_21308\3082868993.py:14: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   'lambda': trial.suggest_loguniform('lambda', 1e-3, 10.0),
# C:\Users\jkpark\AppData\Local\Temp\ipykernel_21308\3082868993.py:15: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   'alpha': trial.suggest_loguniform('alpha', 1e-3, 10.0),
# c:\Python\Python38\lib\site-packages\xgboost\sklearn.py:793: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# [I 2022-10-22 15:46:58,326] Trial 6 finished with value: 3.4738798976789584 and parameters: {'n_estimators': 836, 'max_depth': 10, 'min_child_weight': 273, 'gamma': 1, 'learning_rate': 0.012, 'colsample_bytree': 0.7036636370510823, 'lambda': 0.08980343522503738, 'alpha': 1.4921898460640555, 'subsample': 0.7}. Best is trial 5 with value: 3.0472197719794254.
# C:\Users\jkpark\AppData\Local\Temp\ipykernel_21308\3082868993.py:14: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   'lambda': trial.suggest_loguniform('lambda', 1e-3, 10.0),
# C:\Users\jkpark\AppData\Local\Temp\ipykernel_21308\3082868993.py:15: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   'alpha': trial.suggest_loguniform('alpha', 1e-3, 10.0),
# c:\Python\Python38\lib\site-packages\xgboost\sklearn.py:793: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# [I 2022-10-22 15:49:07,580] Trial 7 finished with value: 3.2713096281341763 and parameters: {'n_estimators': 2788, 'max_depth': 8, 'min_child_weight': 7, 'gamma': 1, 'learning_rate': 0.018, 'colsample_bytree': 0.8242683851234387, 'lambda': 0.19602165167482308, 'alpha': 0.019454105676512075, 'subsample': 1.0}. Best is trial 5 with value: 3.0472197719794254.
# C:\Users\jkpark\AppData\Local\Temp\ipykernel_21308\3082868993.py:14: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   'lambda': trial.suggest_loguniform('lambda', 1e-3, 10.0),
# C:\Users\jkpark\AppData\Local\Temp\ipykernel_21308\3082868993.py:15: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   'alpha': trial.suggest_loguniform('alpha', 1e-3, 10.0),
# c:\Python\Python38\lib\site-packages\xgboost\sklearn.py:793: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# [I 2022-10-22 15:54:55,870] Trial 8 finished with value: 3.107053234667457 and parameters: {'n_estimators': 4148, 'max_depth': 10, 'min_child_weight': 100, 'gamma': 2, 'learning_rate': 0.02, 'colsample_bytree': 0.9654514643886327, 'lambda': 5.542846187352315, 'alpha': 3.7700856744889015, 'subsample': 0.6}. Best is trial 5 with value: 3.0472197719794254.
# C:\Users\jkpark\AppData\Local\Temp\ipykernel_21308\3082868993.py:14: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   'lambda': trial.suggest_loguniform('lambda', 1e-3, 10.0),
# C:\Users\jkpark\AppData\Local\Temp\ipykernel_21308\3082868993.py:15: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   'alpha': trial.suggest_loguniform('alpha', 1e-3, 10.0),
# c:\Python\Python38\lib\site-packages\xgboost\sklearn.py:793: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# [I 2022-10-22 15:57:10,401] Trial 9 finished with value: 3.497232336163183 and parameters: {'n_estimators': 3102, 'max_depth': 8, 'min_child_weight': 176, 'gamma': 1, 'learning_rate': 0.008, 'colsample_bytree': 0.6572627990792441, 'lambda': 0.01779305752720585, 'alpha': 0.11923150876556216, 'subsample': 1.0}. Best is trial 5 with value: 3.0472197719794254.
# C:\Users\jkpark\AppData\Local\Temp\ipykernel_21308\3082868993.py:14: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   'lambda': trial.suggest_loguniform('lambda', 1e-3, 10.0),
# C:\Users\jkpark\AppData\Local\Temp\ipykernel_21308\3082868993.py:15: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   'alpha': trial.suggest_loguniform('alpha', 1e-3, 10.0),
# c:\Python\Python38\lib\site-packages\xgboost\sklearn.py:793: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# [I 2022-10-22 16:20:59,187] Trial 10 finished with value: 3.0538260941885396 and parameters: {'n_estimators': 4944, 'max_depth': 14, 'min_child_weight': 210, 'gamma': 2, 'learning_rate': 0.01, 'colsample_bytree': 0.85948371878085, 'lambda': 0.0010577328018401043, 'alpha': 6.77899837573882, 'subsample': 0.8}. Best is trial 5 with value: 3.0472197719794254.
# C:\Users\jkpark\AppData\Local\Temp\ipykernel_21308\3082868993.py:14: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   'lambda': trial.suggest_loguniform('lambda', 1e-3, 10.0),
# C:\Users\jkpark\AppData\Local\Temp\ipykernel_21308\3082868993.py:15: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   'alpha': trial.suggest_loguniform('alpha', 1e-3, 10.0),
# c:\Python\Python38\lib\site-packages\xgboost\sklearn.py:793: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# [I 2022-10-22 16:45:18,137] Trial 11 finished with value: 3.0557143263760875 and parameters: {'n_estimators': 4910, 'max_depth': 14, 'min_child_weight': 212, 'gamma': 2, 'learning_rate': 0.01, 'colsample_bytree': 0.8759483158276699, 'lambda': 0.0019360986187840182, 'alpha': 6.968123830652176, 'subsample': 0.8}. Best is trial 5 with value: 3.0472197719794254.
# C:\Users\jkpark\AppData\Local\Temp\ipykernel_21308\3082868993.py:14: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   'lambda': trial.suggest_loguniform('lambda', 1e-3, 10.0),
# C:\Users\jkpark\AppData\Local\Temp\ipykernel_21308\3082868993.py:15: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   'alpha': trial.suggest_loguniform('alpha', 1e-3, 10.0),
# c:\Python\Python38\lib\site-packages\xgboost\sklearn.py:793: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# [I 2022-10-22 17:07:50,574] Trial 12 finished with value: 3.0578167875837545 and parameters: {'n_estimators': 4901, 'max_depth': 14, 'min_child_weight': 215, 'gamma': 2, 'learning_rate': 0.01, 'colsample_bytree': 0.9056620649795268, 'lambda': 0.0010135765945276634, 'alpha': 0.4697235184802587, 'subsample': 0.8}. Best is trial 5 with value: 3.0472197719794254.
# C:\Users\jkpark\AppData\Local\Temp\ipykernel_21308\3082868993.py:14: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   'lambda': trial.suggest_loguniform('lambda', 1e-3, 10.0),
# C:\Users\jkpark\AppData\Local\Temp\ipykernel_21308\3082868993.py:15: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   'alpha': trial.suggest_loguniform('alpha', 1e-3, 10.0),
# c:\Python\Python38\lib\site-packages\xgboost\sklearn.py:793: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# [I 2022-10-22 17:52:48,131] Trial 13 finished with value: 3.0307072043340955 and parameters: {'n_estimators': 4218, 'max_depth': 16, 'min_child_weight': 79, 'gamma': 3, 'learning_rate': 0.01, 'colsample_bytree': 0.860656030656683, 'lambda': 0.00298046533111841, 'alpha': 8.527012176131553, 'subsample': 0.8}. Best is trial 13 with value: 3.0307072043340955.
# C:\Users\jkpark\AppData\Local\Temp\ipykernel_21308\3082868993.py:14: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   'lambda': trial.suggest_loguniform('lambda', 1e-3, 10.0),
# C:\Users\jkpark\AppData\Local\Temp\ipykernel_21308\3082868993.py:15: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   'alpha': trial.suggest_loguniform('alpha', 1e-3, 10.0),
# c:\Python\Python38\lib\site-packages\xgboost\sklearn.py:793: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# [I 2022-10-22 18:26:08,499] Trial 14 finished with value: 3.0368623620160764 and parameters: {'n_estimators': 2153, 'max_depth': 16, 'min_child_weight': 66, 'gamma': 3, 'learning_rate': 0.014, 'colsample_bytree': 0.5278334787881918, 'lambda': 0.0036814869878068774, 'alpha': 0.32754493372845395, 'subsample': 0.8}. Best is trial 13 with value: 3.0307072043340955.
# C:\Users\jkpark\AppData\Local\Temp\ipykernel_21308\3082868993.py:14: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   'lambda': trial.suggest_loguniform('lambda', 1e-3, 10.0),
# C:\Users\jkpark\AppData\Local\Temp\ipykernel_21308\3082868993.py:15: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   'alpha': trial.suggest_loguniform('alpha', 1e-3, 10.0),
# c:\Python\Python38\lib\site-packages\xgboost\sklearn.py:793: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# [I 2022-10-22 19:00:13,699] Trial 15 finished with value: 3.0350282486948994 and parameters: {'n_estimators': 2049, 'max_depth': 16, 'min_child_weight': 61, 'gamma': 3, 'learning_rate': 0.014, 'colsample_bytree': 0.5034287031731993, 'lambda': 0.005832570159938316, 'alpha': 0.2699489148528571, 'subsample': 0.8}. Best is trial 13 with value: 3.0307072043340955.
# C:\Users\jkpark\AppData\Local\Temp\ipykernel_21308\3082868993.py:14: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   'lambda': trial.suggest_loguniform('lambda', 1e-3, 10.0),
# C:\Users\jkpark\AppData\Local\Temp\ipykernel_21308\3082868993.py:15: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   'alpha': trial.suggest_loguniform('alpha', 1e-3, 10.0),
# c:\Python\Python38\lib\site-packages\xgboost\sklearn.py:793: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# [I 2022-10-22 19:09:49,060] Trial 16 finished with value: 3.0755731207735577 and parameters: {'n_estimators': 2230, 'max_depth': 12, 'min_child_weight': 61, 'gamma': 3, 'learning_rate': 0.014, 'colsample_bytree': 0.7904921824330103, 'lambda': 0.042070058936611705, 'alpha': 0.05031692349555134, 'subsample': 0.8}. Best is trial 13 with value: 3.0307072043340955.
# C:\Users\jkpark\AppData\Local\Temp\ipykernel_21308\3082868993.py:14: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   'lambda': trial.suggest_loguniform('lambda', 1e-3, 10.0),
# C:\Users\jkpark\AppData\Local\Temp\ipykernel_21308\3082868993.py:15: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   'alpha': trial.suggest_loguniform('alpha', 1e-3, 10.0),
# c:\Python\Python38\lib\site-packages\xgboost\sklearn.py:793: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# [I 2022-10-22 19:44:33,650] Trial 17 finished with value: 3.0320622961348347 and parameters: {'n_estimators': 2149, 'max_depth': 16, 'min_child_weight': 45, 'gamma': 3, 'learning_rate': 0.016, 'colsample_bytree': 0.5118092680409815, 'lambda': 0.005442977883614074, 'alpha': 0.27511148841201927, 'subsample': 0.8}. Best is trial 13 with value: 3.0307072043340955.
# C:\Users\jkpark\AppData\Local\Temp\ipykernel_21308\3082868993.py:14: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   'lambda': trial.suggest_loguniform('lambda', 1e-3, 10.0),
# C:\Users\jkpark\AppData\Local\Temp\ipykernel_21308\3082868993.py:15: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   'alpha': trial.suggest_loguniform('alpha', 1e-3, 10.0),
# c:\Python\Python38\lib\site-packages\xgboost\sklearn.py:793: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# [I 2022-10-22 20:06:08,708] Trial 18 finished with value: 3.047589786509135 and parameters: {'n_estimators': 4240, 'max_depth': 13, 'min_child_weight': 101, 'gamma': 2, 'learning_rate': 0.016, 'colsample_bytree': 0.5639550324853692, 'lambda': 0.045538015114576474, 'alpha': 0.02060165744628936, 'subsample': 0.8}. Best is trial 13 with value: 3.0307072043340955.
# C:\Users\jkpark\AppData\Local\Temp\ipykernel_21308\3082868993.py:14: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   'lambda': trial.suggest_loguniform('lambda', 1e-3, 10.0),
# C:\Users\jkpark\AppData\Local\Temp\ipykernel_21308\3082868993.py:15: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   'alpha': trial.suggest_loguniform('alpha', 1e-3, 10.0),
# c:\Python\Python38\lib\site-packages\xgboost\sklearn.py:793: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# [I 2022-10-22 20:30:57,166] Trial 19 finished with value: 3.0270841941040825 and parameters: {'n_estimators': 2673, 'max_depth': 15, 'min_child_weight': 41, 'gamma': 3, 'learning_rate': 0.016, 'colsample_bytree': 0.7220634398128504, 'lambda': 0.01886252131792545, 'alpha': 0.7071016377733417, 'subsample': 0.8}. Best is trial 19 with value: 3.0270841941040825.
# C:\Users\jkpark\AppData\Local\Temp\ipykernel_21308\3082868993.py:14: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   'lambda': trial.suggest_loguniform('lambda', 1e-3, 10.0),
# C:\Users\jkpark\AppData\Local\Temp\ipykernel_21308\3082868993.py:15: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   'alpha': trial.suggest_loguniform('alpha', 1e-3, 10.0),
# c:\Python\Python38\lib\site-packages\xgboost\sklearn.py:793: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# [I 2022-10-22 20:59:10,123] Trial 20 finished with value: 3.049114596105101 and parameters: {'n_estimators': 2907, 'max_depth': 15, 'min_child_weight': 33, 'gamma': 2, 'learning_rate': 0.012, 'colsample_bytree': 0.7368779476192845, 'lambda': 0.029132489823252613, 'alpha': 3.1946240706821527, 'subsample': 0.6}. Best is trial 19 with value: 3.0270841941040825.
# C:\Users\jkpark\AppData\Local\Temp\ipykernel_21308\3082868993.py:14: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   'lambda': trial.suggest_loguniform('lambda', 1e-3, 10.0),
# C:\Users\jkpark\AppData\Local\Temp\ipykernel_21308\3082868993.py:15: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   'alpha': trial.suggest_loguniform('alpha', 1e-3, 10.0),
# c:\Python\Python38\lib\site-packages\xgboost\sklearn.py:793: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# [I 2022-10-22 21:15:31,041] Trial 21 finished with value: 3.0348987873778785 and parameters: {'n_estimators': 1508, 'max_depth': 15, 'min_child_weight': 41, 'gamma': 3, 'learning_rate': 0.016, 'colsample_bytree': 0.65784787662603, 'lambda': 0.0037338017359259965, 'alpha': 0.47302399399095496, 'subsample': 0.8}. Best is trial 19 with value: 3.0270841941040825.
# C:\Users\jkpark\AppData\Local\Temp\ipykernel_21308\3082868993.py:14: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   'lambda': trial.suggest_loguniform('lambda', 1e-3, 10.0),
# C:\Users\jkpark\AppData\Local\Temp\ipykernel_21308\3082868993.py:15: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   'alpha': trial.suggest_loguniform('alpha', 1e-3, 10.0),
# c:\Python\Python38\lib\site-packages\xgboost\sklearn.py:793: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# [I 2022-10-22 21:36:00,697] Trial 22 finished with value: 3.0376801900878942 and parameters: {'n_estimators': 2428, 'max_depth': 16, 'min_child_weight': 91, 'gamma': 3, 'learning_rate': 0.016, 'colsample_bytree': 0.8206371189176324, 'lambda': 0.016152983996065344, 'alpha': 0.2093357817935244, 'subsample': 0.8}. Best is trial 19 with value: 3.0270841941040825.
# C:\Users\jkpark\AppData\Local\Temp\ipykernel_21308\3082868993.py:14: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   'lambda': trial.suggest_loguniform('lambda', 1e-3, 10.0),
# C:\Users\jkpark\AppData\Local\Temp\ipykernel_21308\3082868993.py:15: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   'alpha': trial.suggest_loguniform('alpha', 1e-3, 10.0),
# c:\Python\Python38\lib\site-packages\xgboost\sklearn.py:793: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# [I 2022-10-22 21:45:52,331] Trial 23 finished with value: 3.0534029267907887 and parameters: {'n_estimators': 1478, 'max_depth': 15, 'min_child_weight': 127, 'gamma': 3, 'learning_rate': 0.016, 'colsample_bytree': 0.9341709275534933, 'lambda': 0.004253750975702548, 'alpha': 0.8492201700968383, 'subsample': 0.8}. Best is trial 19 with value: 3.0270841941040825.
# C:\Users\jkpark\AppData\Local\Temp\ipykernel_21308\3082868993.py:14: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   'lambda': trial.suggest_loguniform('lambda', 1e-3, 10.0),
# C:\Users\jkpark\AppData\Local\Temp\ipykernel_21308\3082868993.py:15: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   'alpha': trial.suggest_loguniform('alpha', 1e-3, 10.0),
# c:\Python\Python38\lib\site-packages\xgboost\sklearn.py:793: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# [I 2022-10-22 21:58:14,640] Trial 24 finished with value: 3.0713739907373547 and parameters: {'n_estimators': 2507, 'max_depth': 13, 'min_child_weight': 35, 'gamma': 3, 'learning_rate': 0.01, 'colsample_bytree': 0.6562383682169182, 'lambda': 0.131729426706125, 'alpha': 9.425471338220191, 'subsample': 0.8}. Best is trial 19 with value: 3.0270841941040825.
# C:\Users\jkpark\AppData\Local\Temp\ipykernel_21308\3082868993.py:14: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   'lambda': trial.suggest_loguniform('lambda', 1e-3, 10.0),
# C:\Users\jkpark\AppData\Local\Temp\ipykernel_21308\3082868993.py:15: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   'alpha': trial.suggest_loguniform('alpha', 1e-3, 10.0),
# c:\Python\Python38\lib\site-packages\xgboost\sklearn.py:793: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# [I 2022-10-22 22:20:17,211] Trial 25 finished with value: 3.0374212142790062 and parameters: {'n_estimators': 1833, 'max_depth': 16, 'min_child_weight': 78, 'gamma': 3, 'learning_rate': 0.008, 'colsample_bytree': 0.8407752901718906, 'lambda': 0.015499742064576561, 'alpha': 3.129199420500079, 'subsample': 0.8}. Best is trial 19 with value: 3.0270841941040825.
# C:\Users\jkpark\AppData\Local\Temp\ipykernel_21308\3082868993.py:14: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   'lambda': trial.suggest_loguniform('lambda', 1e-3, 10.0),
# C:\Users\jkpark\AppData\Local\Temp\ipykernel_21308\3082868993.py:15: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   'alpha': trial.suggest_loguniform('alpha', 1e-3, 10.0),
# c:\Python\Python38\lib\site-packages\xgboost\sklearn.py:793: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# [I 2022-10-22 22:38:57,895] Trial 26 finished with value: 3.0408767289686573 and parameters: {'n_estimators': 3176, 'max_depth': 15, 'min_child_weight': 137, 'gamma': 2, 'learning_rate': 0.016, 'colsample_bytree': 0.7679926792041666, 'lambda': 0.002494751313697114, 'alpha': 0.7408525524963845, 'subsample': 0.8}. Best is trial 19 with value: 3.0270841941040825.
# C:\Users\jkpark\AppData\Local\Temp\ipykernel_21308\3082868993.py:14: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   'lambda': trial.suggest_loguniform('lambda', 1e-3, 10.0),
# C:\Users\jkpark\AppData\Local\Temp\ipykernel_21308\3082868993.py:15: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   'alpha': trial.suggest_loguniform('alpha', 1e-3, 10.0),
# c:\Python\Python38\lib\site-packages\xgboost\sklearn.py:793: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# [I 2022-10-22 22:56:40,799] Trial 27 finished with value: 3.0168951916659785 and parameters: {'n_estimators': 4519, 'max_depth': 13, 'min_child_weight': 22, 'gamma': 3, 'learning_rate': 0.016, 'colsample_bytree': 0.7242144738048932, 'lambda': 0.007923992135983554, 'alpha': 0.13203244419302776, 'subsample': 0.8}. Best is trial 27 with value: 3.0168951916659785.
# C:\Users\jkpark\AppData\Local\Temp\ipykernel_21308\3082868993.py:14: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   'lambda': trial.suggest_loguniform('lambda', 1e-3, 10.0),
# C:\Users\jkpark\AppData\Local\Temp\ipykernel_21308\3082868993.py:15: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   'alpha': trial.suggest_loguniform('alpha', 1e-3, 10.0),
# c:\Python\Python38\lib\site-packages\xgboost\sklearn.py:793: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# [I 2022-10-22 23:19:48,662] Trial 28 finished with value: 3.049294688334956 and parameters: {'n_estimators': 4433, 'max_depth': 13, 'min_child_weight': 20, 'gamma': 3, 'learning_rate': 0.01, 'colsample_bytree': 0.7293122214760211, 'lambda': 0.3235137587029494, 'alpha': 0.0399907446023752, 'subsample': 0.6}. Best is trial 27 with value: 3.0168951916659785.
# C:\Users\jkpark\AppData\Local\Temp\ipykernel_21308\3082868993.py:14: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   'lambda': trial.suggest_loguniform('lambda', 1e-3, 10.0),
# C:\Users\jkpark\AppData\Local\Temp\ipykernel_21308\3082868993.py:15: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   'alpha': trial.suggest_loguniform('alpha', 1e-3, 10.0),
# c:\Python\Python38\lib\site-packages\xgboost\sklearn.py:793: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# [I 2022-10-22 23:24:04,061] Trial 29 finished with value: 3.1148375919215083 and parameters: {'n_estimators': 4422, 'max_depth': 12, 'min_child_weight': 83, 'gamma': 3, 'learning_rate': 0.016, 'colsample_bytree': 0.8032325354151056, 'lambda': 0.009104691343117576, 'alpha': 0.004800088329545125, 'subsample': 1.0}. Best is trial 27 with value: 3.0168951916659785.
# Best trial: score 3.0168951916659785,
# params {'n_estimators': 4519, 'max_depth': 13, 'min_child_weight': 22, 'gamma': 3, 'learning_rate': 0.016, 'colsample_bytree': 0.7242144738048932, 'lambda': 0.007923992135983554, 'alpha': 0.13203244419302776, 'subsample': 0.8}

# %% [markdown]
# params {'n_estimators': 4519, 'max_depth': 13, 'min_child_weight': 22, 'gamma': 3, 'learning_rate': 0.016, 'colsample_bytree': 0.7242144738048932, 'lambda': 0.007923992135983554, 'alpha': 0.13203244419302776, 'subsample': 0.8}

# %%
study.best_trial.params
# Out:
# {'n_estimators': 4519,
#  'max_depth': 13,
#  'min_child_weight': 22,
#  'gamma': 3,
#  'learning_rate': 0.016,
#  'colsample_bytree': 0.7242144738048932,
#  'lambda': 0.007923992135983554,
#  'alpha': 0.13203244419302776,
#  'subsample': 0.8}

# %%
from sklearn.model_selection import StratifiedKFold
from xgboost import XGBRegressor
from sklearn.metrics import mean_absolute_error


param = study.best_trial.params

skf = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)

folds = []

for train_idx, val_idx in skf.split(X, y):
    folds.append((train_idx, val_idx))

XGB_model= {}

for f in range(5):
      print(f'===================================={f+1}============================================')
      train_idx, val_idx = folds[f]
      
      x_train, x_val, y_train, y_val = X.iloc[train_idx], X.iloc[val_idx], y.iloc[train_idx], y.iloc[val_idx]
      
      XGB = XGBRegressor(**param, tree_method='gpu_hist', gpu_id=0)
      XGB.fit(x_train, y_train)
      
      y_pred = XGB.predict(x_val)
      mae = mean_absolute_error(y_val, y_pred)
      print(f"{f + 1} Fold MAE = {mae}")
      XGB_model[f] = XGB
      print(f'================================================================================\n\n')
              


for fold in range(5):
    sample_submission['target'] += XGB_model[fold].predict(test)/5
# Out:
# c:\Python\Python38\lib\site-packages\sklearn\model_selection\_split.py:680: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=5.
#   warnings.warn(
# ====================================1============================================
# 1 Fold MAE = 3.021009554121474
# ================================================================================
#
#
# ====================================2============================================
# 2 Fold MAE = 3.019629712531273
# ================================================================================
#
#
# ====================================3============================================
# 3 Fold MAE = 3.016938838577998
# ================================================================================
#
#
# ====================================4============================================
# 4 Fold MAE = 3.0173574349745227
# ================================================================================
#
#
# ====================================5============================================
# 5 Fold MAE = 3.016860395132144
# ================================================================================

# %%
df_imp = pd.DataFrame({'imp':XGB.feature_importances_}, index = XGB.feature_names_in_)
df_imp = df_imp[df_imp.imp > 0].sort_values('imp').copy()
df_imp
# Out:
#                             imp
# day_of_week            0.000740
# post_holiday           0.000754
# pre_holiday            0.000923
# vacation               0.001018
# holiday                0.001093
# week                   0.001368
# multi_linked           0.001387
# month                  0.001574
# season                 0.003486
# sin_time               0.003757
# cos_time               0.006333
# end_turn_restricted    0.010998
# time                   0.013484
# start_turn_restricted  0.013810
# distance               0.025650
# road_type              0.029034
# start_latitude         0.032048
# lane_count             0.032609
# end_latitude           0.037562
# start_longitude        0.040851
# turn_restricted        0.043507
# weight_restricted      0.045195
# end_longitude          0.069269
# road_rating            0.101951
# maximum_speed_limit    0.211740
# connect_code           0.269861

# %%
sample_submission.to_csv("./submit_xgb_fold.csv", index=False)
